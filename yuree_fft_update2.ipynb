# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import os
folder_path = r"C:\Users\medici\901"
file_name = "learning2_data.csv"
file_path = os.path.join(folder_path, file_name)

data2 = pd.read_csv(file_path)

print(data2.head())
# Out:
#    Unnamed: 0         0         1         2         3         4         5  \
# 0           0  3.899300  7.565520  1.296009 -6.861289 -5.934815  4.148840
# 1           1 -0.951626 -0.026867  0.475558 -0.157340 -0.342464  0.165069
# 2           2 -3.929285 -7.165016 -0.110136  4.738086  2.834087 -1.568131
# 3           3 -2.782683  5.760739  3.001560 -5.608408 -2.907724  5.079184
# 4           4 -0.272671 -0.121940 -0.026397  0.054517 -0.398982 -0.034386
#
#           6         7         8  ...     25591     25592     25593     25594  \
# 0  8.311052 -0.166117 -6.853495  ...  0.295866 -1.204017 -1.127772  1.916237
# 1  0.143682 -0.368740 -0.219467  ... -0.207053  0.030481  0.001685 -0.389913
# 2 -3.172974 -1.409300  0.567256  ... -5.573459 -4.879050  4.606160  4.547146
# 3  2.826995 -4.344326 -2.332803  ...  0.452963 -0.050988 -0.799437 -0.406508
# 4  0.324217  0.461581 -0.208683  ...  0.178991  0.331815  0.082452  0.144409
#
#       25595     25596     25597     25598     25599  fault_type
# 0  2.095459 -2.029180 -5.232660  1.396363  7.535430           1
# 1 -0.147019  0.320774 -0.054070 -0.336892  0.117773           1
# 2 -4.647161 -3.728426  5.277608  3.435046 -5.358367           1
# 3 -0.030547 -0.112657 -0.351845 -0.337875 -0.369204           1
# 4  0.025489 -0.240097 -0.179325  0.124719  0.158147           1
#
# [5 rows x 25602 columns]

# %%
data2=data2.drop('Unnamed: 0', axis=1)

# %%
data2
# Out:
#              0         1         2         3         4         5         6  \
# 0     3.899300  7.565520  1.296009 -6.861289 -5.934815  4.148840  8.311052
# 1    -0.951626 -0.026867  0.475558 -0.157340 -0.342464  0.165069  0.143682
# 2    -3.929285 -7.165016 -0.110136  4.738086  2.834087 -1.568131 -3.172974
# 3    -2.782683  5.760739  3.001560 -5.608408 -2.907724  5.079184  2.826995
# 4    -0.272671 -0.121940 -0.026397  0.054517 -0.398982 -0.034386  0.324217
# ...        ...       ...       ...       ...       ...       ...       ...
# 1234 -0.052208 -0.047765 -0.057964 -0.077043 -0.010430 -0.000896 -0.038360
# 1235  0.016248  0.038758  0.070990  0.059766 -0.023504 -0.034588  0.012580
# 1236  0.012629 -0.012334 -0.036590  0.050409  0.040265  0.059400 -0.026275
# 1237 -0.144944 -0.141777  0.059033  0.094421  0.037653  0.050934  0.086682
# 1238 -0.085161 -0.022576 -0.021606  0.043750  0.036377  0.074622 -0.001781
#
#              7         8         9  ...     25591     25592     25593  \
# 0    -0.166117 -6.853495 -4.057329  ...  0.295866 -1.204017 -1.127772
# 1    -0.368740 -0.219467  0.256157  ... -0.207053  0.030481  0.001685
# 2    -1.409300  0.567256  3.044535  ... -5.573459 -4.879050  4.606160
# 3    -4.344326 -2.332803  4.276500  ...  0.452963 -0.050988 -0.799437
# 4     0.461581 -0.208683 -0.133903  ...  0.178991  0.331815  0.082452
# ...        ...       ...       ...  ...       ...       ...       ...
# 1234 -0.003680  0.028351  0.063056  ... -0.131187 -0.070836 -0.014751
# 1235 -0.070610 -0.062291 -0.029186  ...  0.061585  0.074139  0.009022
# 1236  0.041706  0.084198  0.056348  ...  0.169872  0.009046  0.147631
# 1237 -0.025554 -0.001824  0.029017  ...  0.091125 -0.028356 -0.137260
# 1238  0.020698 -0.026549 -0.043938  ...  0.029377  0.015473 -0.030938
#
#          25594     25595     25596     25597     25598     25599  fault_type
# 0     1.916237  2.095459 -2.029180 -5.232660  1.396363  7.535430           1
# 1    -0.389913 -0.147019  0.320774 -0.054070 -0.336892  0.117773           1
# 2     4.547146 -4.647161 -3.728426  5.277608  3.435046 -5.358367           1
# 3    -0.406508 -0.030547 -0.112657 -0.351845 -0.337875 -0.369204           1
# 4     0.144409  0.025489 -0.240097 -0.179325  0.124719  0.158147           1
# ...        ...       ...       ...       ...       ...       ...         ...
# 1234 -0.022985 -0.063500 -0.070610  0.041211  0.067359 -0.003533           0
# 1235 -0.022179  0.018452  0.001435 -0.043908 -0.009173  0.078699           0
# 1236  0.093811 -0.103642 -0.123845 -0.017547  0.111096  0.095404           0
# 1237 -0.060539  0.060279  0.118090 -0.005169 -0.002489 -0.086101           0
# 1238 -0.097569 -0.068968  0.002888  0.004157  0.031318  0.076691           0
#
# [1239 rows x 25601 columns]

# %% [markdown]
# ## 내륜결함

# %%
ftf_freq = 12.10
bpfo_freq = 157.26
bpfi_freq = 232.74
bsf_freq = 76.03

# %%
inner_first_row = data2.iloc[0, :-1].values


sampling_rate = 25600
fft_values = np.fft.fft(inner_first_row)
fft_magnitude = np.abs(fft_values)  # Get magnitude of the FFT
n = len(inner_first_row)
frequencies = np.fft.fftfreq(n, d=1/sampling_rate)

# 주파수 필터링: 0 이상의 주파수만 사용 (양수 주파수만 필터링)
positive_freqs = frequencies[:n // 2]
fft_magnitude = fft_magnitude[:n // 2]

# 결함 주파수에 대한 대역폭 (필터링 범위를 설정합니다)
bandwidth = 20  # 대역폭 설정

# 주파수 필터링 (결함 주파수 범위에 해당하는 부분만 선택)
bpfo_range = (positive_freqs > bpfo_freq - bandwidth) & (positive_freqs < bpfo_freq + bandwidth)
bpfi_range = (positive_freqs > bpfi_freq - bandwidth) & (positive_freqs < bpfi_freq + bandwidth)
ftf_range = (positive_freqs > ftf_freq - bandwidth) & (positive_freqs < ftf_freq + bandwidth)
bsf_range = (positive_freqs > bsf_freq - bandwidth) & (positive_freqs < bsf_freq + bandwidth)

# 0 ~ 300Hz 범위 필터링
max_freq = 300
freq_range = (positive_freqs >= 0) & (positive_freqs <= max_freq)

# 그래프 그리기
plt.figure(figsize=(10, 6))
plt.plot(positive_freqs[freq_range], fft_magnitude[freq_range], label='FFT Magnitude')

# 결함 주파수 범위 강조 표시
plt.plot(positive_freqs[bpfo_range], fft_magnitude[bpfo_range], 'r', label='BPFO Range')
plt.plot(positive_freqs[bpfi_range], fft_magnitude[bpfi_range], 'g', label='BPFI Range')
plt.plot(positive_freqs[ftf_range], fft_magnitude[ftf_range], 'b', label='FTF Range')
plt.plot(positive_freqs[bsf_range], fft_magnitude[bsf_range], 'y', label='BSF Range')

# 결함 주파수에 대한 수직선 추가
plt.axvline(x=ftf_freq, color='b', linestyle='--', label=f'FTF: {ftf_freq} Hz')
plt.axvline(x=bpfo_freq, color='r', linestyle='--', label=f'BPFO: {bpfo_freq} Hz')
plt.axvline(x=bpfi_freq, color='g', linestyle='--', label=f'BPFI: {bpfi_freq} Hz')
plt.axvline(x=bsf_freq, color='y', linestyle='--', label=f'BSF: {bsf_freq} Hz')

# 그래프 레이블과 제목
plt.title('Filtered BPFI Spectrum with Defect Frequencies Highlighted')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Magnitude')
plt.legend()

# 그래프 표시
plt.grid(True)
plt.show()

# %%
roller_first_row = data2.iloc[310, :-1].values


sampling_rate = 25600
fft_values = np.fft.fft(roller_first_row)
fft_magnitude = np.abs(fft_values)  # Get magnitude of the FFT
n = len(roller_first_row)
frequencies = np.fft.fftfreq(n, d=1/sampling_rate)

# 주파수 필터링: 0 이상의 주파수만 사용 (양수 주파수만 필터링)
positive_freqs = frequencies[:n // 2]
fft_magnitude = fft_magnitude[:n // 2]

# 결함 주파수에 대한 대역폭 (필터링 범위를 설정합니다)
bandwidth = 20  # 대역폭 설정

# 주파수 필터링 (결함 주파수 범위에 해당하는 부분만 선택)
bpfo_range = (positive_freqs > bpfo_freq - bandwidth) & (positive_freqs < bpfo_freq + bandwidth)
bpfi_range = (positive_freqs > bpfi_freq - bandwidth) & (positive_freqs < bpfi_freq + bandwidth)
ftf_range = (positive_freqs > ftf_freq - bandwidth) & (positive_freqs < ftf_freq + bandwidth)
bsf_range = (positive_freqs > bsf_freq - bandwidth) & (positive_freqs < bsf_freq + bandwidth)

# 0 ~ 300Hz 범위 필터링
max_freq = 300
freq_range = (positive_freqs >= 0) & (positive_freqs <= max_freq)

# 그래프 그리기
plt.figure(figsize=(10, 6))
plt.plot(positive_freqs[freq_range], fft_magnitude[freq_range], label='FFT Magnitude')

# 결함 주파수 범위 강조 표시
plt.plot(positive_freqs[bpfo_range], fft_magnitude[bpfo_range], 'r', label='BPFO Range')
plt.plot(positive_freqs[bpfi_range], fft_magnitude[bpfi_range], 'g', label='BPFI Range')
plt.plot(positive_freqs[ftf_range], fft_magnitude[ftf_range], 'b', label='FTF Range')
plt.plot(positive_freqs[bsf_range], fft_magnitude[bsf_range], 'y', label='BSF Range')

# 결함 주파수에 대한 수직선 추가
plt.axvline(x=ftf_freq, color='b', linestyle='--', label=f'FTF: {ftf_freq} Hz')
plt.axvline(x=bpfo_freq, color='r', linestyle='--', label=f'BPFO: {bpfo_freq} Hz')
plt.axvline(x=bpfi_freq, color='g', linestyle='--', label=f'BPFI: {bpfi_freq} Hz')
plt.axvline(x=bsf_freq, color='y', linestyle='--', label=f'BSF: {bsf_freq} Hz')

# 그래프 레이블과 제목
plt.title('Filtered BSF Spectrum with Defect Frequencies Highlighted')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Magnitude')
plt.legend()

# 그래프 표시
plt.grid(True)
plt.show()

# %%
outer_first_row = data2.iloc[620, :-1].values


sampling_rate = 25600
fft_values = np.fft.fft(outer_first_row)
fft_magnitude = np.abs(fft_values)  # Get magnitude of the FFT
n = len(outer_first_row)
frequencies = np.fft.fftfreq(n, d=1/sampling_rate)

# 주파수 필터링: 0 이상의 주파수만 사용 (양수 주파수만 필터링)
positive_freqs = frequencies[:n // 2]
fft_magnitude = fft_magnitude[:n // 2]

# 결함 주파수에 대한 대역폭 (필터링 범위를 설정합니다)
bandwidth = 20  # 대역폭 설정

# 주파수 필터링 (결함 주파수 범위에 해당하는 부분만 선택)
bpfo_range = (positive_freqs > bpfo_freq - bandwidth) & (positive_freqs < bpfo_freq + bandwidth)
bpfi_range = (positive_freqs > bpfi_freq - bandwidth) & (positive_freqs < bpfi_freq + bandwidth)
ftf_range = (positive_freqs > ftf_freq - bandwidth) & (positive_freqs < ftf_freq + bandwidth)
bsf_range = (positive_freqs > bsf_freq - bandwidth) & (positive_freqs < bsf_freq + bandwidth)

# 0 ~ 300Hz 범위 필터링
max_freq = 300
freq_range = (positive_freqs >= 0) & (positive_freqs <= max_freq)

# 그래프 그리기
plt.figure(figsize=(10, 6))
plt.plot(positive_freqs[freq_range], fft_magnitude[freq_range], label='FFT Magnitude')

# 결함 주파수 범위 강조 표시
plt.plot(positive_freqs[bpfo_range], fft_magnitude[bpfo_range], 'r', label='BPFO Range')
plt.plot(positive_freqs[bpfi_range], fft_magnitude[bpfi_range], 'g', label='BPFI Range')
plt.plot(positive_freqs[ftf_range], fft_magnitude[ftf_range], 'b', label='FTF Range')
plt.plot(positive_freqs[bsf_range], fft_magnitude[bsf_range], 'y', label='BSF Range')

# 결함 주파수에 대한 수직선 추가
plt.axvline(x=ftf_freq, color='b', linestyle='--', label=f'FTF: {ftf_freq} Hz')
plt.axvline(x=bpfo_freq, color='r', linestyle='--', label=f'BPFO: {bpfo_freq} Hz')
plt.axvline(x=bpfi_freq, color='g', linestyle='--', label=f'BPFI: {bpfi_freq} Hz')
plt.axvline(x=bsf_freq, color='y', linestyle='--', label=f'BSF: {bsf_freq} Hz')

# 그래프 레이블과 제목
plt.title('Filtered BPFO Spectrum with Defect Frequencies Highlighted')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Magnitude')
plt.legend()

# 그래프 표시
plt.grid(True)
plt.show()

# %%
normal_first_row = data2.iloc[930, :-1].values


sampling_rate = 25600
fft_values = np.fft.fft(normal_first_row)
fft_magnitude = np.abs(fft_values)  # Get magnitude of the FFT
n = len(normal_first_row)
frequencies = np.fft.fftfreq(n, d=1/sampling_rate)

# 주파수 필터링: 0 이상의 주파수만 사용 (양수 주파수만 필터링)
positive_freqs = frequencies[:n // 2]
fft_magnitude = fft_magnitude[:n // 2]

# 결함 주파수에 대한 대역폭 (필터링 범위를 설정합니다)
bandwidth = 20  # 대역폭 설정

# 주파수 필터링 (결함 주파수 범위에 해당하는 부분만 선택)
bpfo_range = (positive_freqs > bpfo_freq - bandwidth) & (positive_freqs < bpfo_freq + bandwidth)
bpfi_range = (positive_freqs > bpfi_freq - bandwidth) & (positive_freqs < bpfi_freq + bandwidth)
ftf_range = (positive_freqs > ftf_freq - bandwidth) & (positive_freqs < ftf_freq + bandwidth)
bsf_range = (positive_freqs > bsf_freq - bandwidth) & (positive_freqs < bsf_freq + bandwidth)

# 0 ~ 300Hz 범위 필터링
max_freq = 300
freq_range = (positive_freqs >= 0) & (positive_freqs <= max_freq)

# 그래프 그리기
plt.figure(figsize=(10, 6))
plt.plot(positive_freqs[freq_range], fft_magnitude[freq_range], label='FFT Magnitude')

# 결함 주파수 범위 강조 표시
plt.plot(positive_freqs[bpfo_range], fft_magnitude[bpfo_range], 'r', label='BPFO Range')
plt.plot(positive_freqs[bpfi_range], fft_magnitude[bpfi_range], 'g', label='BPFI Range')
plt.plot(positive_freqs[ftf_range], fft_magnitude[ftf_range], 'b', label='FTF Range')
plt.plot(positive_freqs[bsf_range], fft_magnitude[bsf_range], 'y', label='BSF Range')

# 결함 주파수에 대한 수직선 추가
plt.axvline(x=ftf_freq, color='b', linestyle='--', label=f'FTF: {ftf_freq} Hz')
plt.axvline(x=bpfo_freq, color='r', linestyle='--', label=f'BPFO: {bpfo_freq} Hz')
plt.axvline(x=bpfi_freq, color='g', linestyle='--', label=f'BPFI: {bpfi_freq} Hz')
plt.axvline(x=bsf_freq, color='y', linestyle='--', label=f'BSF: {bsf_freq} Hz')

# 그래프 레이블과 제목
plt.title('Filtered Normal Spectrum with Defect Frequencies Highlighted')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Magnitude')
plt.legend()

# 그래프 표시
plt.grid(True)
plt.show()

# %%
# 1. 각 인덱스 그룹을 다른 데이터프레임/넘파이로 만들기
inner = data2.iloc[0:310, :]   # 0 ~ 119
roller = data2.iloc[310:620, :]  # 120 ~ 239
outer = data2.iloc[620:930, :]  # 240 ~ 359
normal = data2.iloc[930:1239, :]  # 360 ~ 479

# 필요한 주파수와 샘플링 레이트 설정
sampling_rate = 25600  # 25.6 kHz 샘플링 레이트
ftf_freq = 12.10
bpfo_freq = 157.26
bpfi_freq = 232.74
bsf_freq = 76.03

# 주파수와 진폭의 세기를 계산하는 함수
def calculate_fft_magnitude(data_group, sampling_rate, target_freqs, bandwidth=30):
    fft_magnitudes = []
    frequencies = np.fft.fftfreq(data_group.shape[1], d=1/sampling_rate)
    
    for _, signal in data_group.iterrows():
        # FFT 변환
        fft_values = np.fft.fft(signal)
        fft_magnitude = np.abs(fft_values)[:len(fft_values)//2]  # 양수 주파수만 선택
        pos_frequencies = frequencies[:len(frequencies)//2]  # 양수 주파수

        group_magnitudes = {}
        for freq in target_freqs:
            # 주파수 범위 설정: 음수 주파수는 0Hz로 제한
            low_bound = max(0, freq - bandwidth)  # 음수가 나오지 않도록 처리
            high_bound = freq + bandwidth

            # 주파수 대역 설정
            freq_range = (pos_frequencies >= low_bound) & (pos_frequencies <= high_bound)
            # 대역 내에서 진폭 합산
            magnitude_in_range = np.sum(fft_magnitude[freq_range])
            group_magnitudes[f'Freq_{freq}Hz'] = magnitude_in_range
        
        fft_magnitudes.append(group_magnitudes)
    
    return pd.DataFrame(fft_magnitudes)

# 2. 각 인덱스 그룹에서 주파수의 세기를 계산
target_frequencies = [ftf_freq, bpfo_freq, bpfi_freq, bsf_freq]

# 각 그룹의 주파수 세기를 계산
inner_magnitude = calculate_fft_magnitude(inner, sampling_rate, target_frequencies)
roller_magnitude = calculate_fft_magnitude(roller, sampling_rate, target_frequencies)
outer_magnitude = calculate_fft_magnitude(outer, sampling_rate, target_frequencies)
normal_magnitude = calculate_fft_magnitude(normal, sampling_rate, target_frequencies)

# 3. 그래프를 그리기 위한 예시
plt.figure(figsize=(10, 6))
plt.plot(inner_magnitude, label="Inner Magnitude")
plt.plot(roller_magnitude, label="Roller Magnitude")
plt.plot(outer_magnitude, label="Outer Magnitude")
plt.plot(normal_magnitude, label="Normal Magnitude")
plt.legend()
plt.grid(True)
plt.title("Frequency Magnitude for each Group")
plt.xlabel("Sample Index")
plt.ylabel("Magnitude")
plt.show()

# %%
# 주파수별로 차트를 분리하여 그리기
plt.figure(figsize=(10, 12))

# 각 주파수마다 별도의 차트를 생성
for idx, freq in enumerate(target_frequencies):
    plt.subplot(4, 1, idx + 1)
    plt.plot(inner_magnitude[f'Freq_{freq}Hz'], label='Inner Magnitude')
    plt.plot(roller_magnitude[f'Freq_{freq}Hz'], label='Roller Magnitude')
    plt.plot(outer_magnitude[f'Freq_{freq}Hz'], label='Outer Magnitude')
    plt.plot(normal_magnitude[f'Freq_{freq}Hz'], label='Normal Magnitude')
    
    plt.title(f'Magnitude for Frequency {freq}Hz')
    plt.xlabel('Sample Index')
    plt.ylabel('Magnitude')
    plt.legend()
    plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # [내륜결함]

# %% [markdown]
# ## [Shapiro-Wilk 정규성 검정]
#  * 귀무가설: 데이터가 정규 분포를 따를 것이다.
#  * p-value < 0.05인 경우: 귀무가설을 기각하므로, Normal을 제외한 나머지 데이터가 정규 분포를 따르지 않는다.

# %%
from scipy.stats import shapiro

datasets = {
    'Inner': inner_magnitude['Freq_232.74Hz'],
    'Outer': outer_magnitude['Freq_232.74Hz'],
    'Roller': roller_magnitude['Freq_232.74Hz'],
    'Normal': normal_magnitude['Freq_232.74Hz']
}

# 각 데이터셋에 대해 정규성 검정 수행
for name, data in datasets.items():
    w_stat, p_value = shapiro(data)
    print(f"{name} - W-statistic: {w_stat}, p-value: {p_value}")
# Out:
# Inner - W-statistic: 0.9900071451877309, p-value: 0.033040438503172696
# Outer - W-statistic: 0.9876992688750389, p-value: 0.01000079494456954
# Roller - W-statistic: 0.9663416285911434, p-value: 1.349321227306202e-06
# Normal - W-statistic: 0.9935112558617896, p-value: 0.2072612200795394

# %% [markdown]
# ## [Mann-Whitney U 검정]
#  * 비모수 검정
#  * 두 그룹 간의 차이를 비교할 때 데이터가 정규 분포를 따르지 않는 경우에도 사용
#  * 순위 기반으로 두 그룹의 차이를 평가
#  * 결론 : 모든 비교에서 p-value가 매우 낮아(유의 수준 0.05보다 작음) Inner 데이터의 Freq_219.7Hz 값이 다른 데이터셋과 유의미하게 차이가 있다

# %%
inner_232 = inner_magnitude['Freq_232.74Hz']
outer_232 = outer_magnitude['Freq_232.74Hz']
roller_232 = roller_magnitude['Freq_232.74Hz']
normal_232 =  normal_magnitude['Freq_232.74Hz']

# %%
from scipy.stats import mannwhitneyu

# Mann-Whitney U 검정
u_outer, p_outer = mannwhitneyu(inner_232, outer_232)
u_roller, p_roller = mannwhitneyu(inner_232, roller_232)
u_normal, p_normal = mannwhitneyu(inner_232, normal_232)

print("Inner vs Outer - U-statistic:", u_outer, ", p-value:", p_outer)
print("Inner vs Roller - U-statistic:", u_roller, ", p-value:", p_roller)
print("Inner vs Normal - U-statistic:", u_normal, ", p-value:", p_normal)
# Out:
# Inner vs Outer - U-statistic: 95454.0 , p-value: 1.5818483740552286e-102
# Inner vs Roller - U-statistic: 95481.0 , p-value: 1.2170075594899933e-102
# Inner vs Normal - U-statistic: 95172.0 , p-value: 1.7732563113966688e-102

# %% [markdown]
# ## [Kruskal-Wallis 검정 코드]
#  * 세 개 이상의 그룹 간의 차이를 검정할 때 사용되는 비모수 검정
#  * 데이터가 정규 분포를 따르지 않는 경우에도 사용
#  * p-value가 1.547e-42로 매우 작기 때문에(일반적으로 유의 수준인 0.05보다 훨씬 작음), 귀무가설을 기각합니다.
#  * 귀무가설: 모든 그룹의 중앙값이 동일하다.

# %%
from scipy.stats import kruskal

# Kruskal-Wallis 검정 수행
kruskal_stat, kruskal_p_value = kruskal(inner_232, outer_232, roller_232, normal_232)

print("Kruskal-Wallis H-statistic:", kruskal_stat)
print("p-value:", kruskal_p_value)
# Out:
# Kruskal-Wallis H-statistic: 1141.5211691643499
# p-value: 3.571820522015293e-247

# %%
plt.figure(figsize=(10, 6))
plt.boxplot([inner_232, outer_232, roller_232, normal_232], tick_labels=['Inner', 'Outer', 'Roller', 'Normal'])
plt.title('Distribution of Freq_232.74Hz for Different Datasets')
plt.ylabel('Magnitude')
plt.grid(True)
plt.show()

# %% [markdown]
# # [롤러 결함]

# %%
datasets = {
    'Inner': inner_magnitude['Freq_76.03Hz'],
    'Outer': outer_magnitude['Freq_76.03Hz'],
    'Roller': roller_magnitude['Freq_76.03Hz'],
    'Normal': normal_magnitude['Freq_76.03Hz']
}

# 각 데이터셋에 대해 정규성 검정 수행
for name, data in datasets.items():
    w_stat, p_value = shapiro(data)
    print(f"{name} - W-statistic: {w_stat}, p-value: {p_value}")

#Outer, Normal 정규성X
# Out:
# Inner - W-statistic: 0.9930420773256565, p-value: 0.1618324533150216
# Outer - W-statistic: 0.9145032510722649, p-value: 2.9126684153767276e-12
# Roller - W-statistic: 0.9950757335266563, p-value: 0.43081003462627376
# Normal - W-statistic: 0.987061307492228, p-value: 0.007383645184583398

# %%
inner_76 = inner_magnitude['Freq_76.03Hz']
outer_76 = outer_magnitude['Freq_76.03Hz']
roller_76 = roller_magnitude['Freq_76.03Hz']
normal_76 =  normal_magnitude['Freq_76.03Hz']

# %%
# Mann-Whitney U 검정
u_outer, p_outer = mannwhitneyu(inner_76, outer_76)
u_roller, p_roller = mannwhitneyu(outer_76, roller_76)
u_normal, p_normal = mannwhitneyu(outer_76, normal_76)

print("Inner vs Outer - U-statistic:", u_outer, ", p-value:", p_outer)
print("Inner vs Roller - U-statistic:", u_roller, ", p-value:", p_roller)
print("Inner vs Normal - U-statistic:", u_normal, ", p-value:", p_normal)
# Out:
# Inner vs Outer - U-statistic: 90620.0 , p-value: 3.570794415570414e-83
# Inner vs Roller - U-statistic: 13.0 , p-value: 1.3807922419952637e-102
# Inner vs Normal - U-statistic: 95172.0 , p-value: 1.7732563113966688e-102

# %%
# Kruskal-Wallis 검정 수행
kruskal_stat, kruskal_p_value = kruskal(inner_76, outer_76, roller_76, normal_76)

print("Kruskal-Wallis H-statistic:", kruskal_stat)
print("p-value:", kruskal_p_value)
# Out:
# Kruskal-Wallis H-statistic: 1134.3383333912116
# p-value: 1.2919756269151317e-245

# %%
plt.figure(figsize=(10, 6))
plt.boxplot([inner_76, outer_76, roller_76, normal_76], tick_labels=['Inner', 'Outer', 'Roller', 'Normal'])
plt.title('Distribution of Freq_76Hz for Different Datasets')
plt.ylabel('Magnitude')
plt.grid(True)
plt.show()

# %% [markdown]
# # [외륜결함]

# %%
# 정규성 검정을 위한 Freq_157.26Hz 열 추출
datasets = {
    'Inner': inner_magnitude['Freq_157.26Hz'],
    'Outer': outer_magnitude['Freq_157.26Hz'],
    'Roller': roller_magnitude['Freq_157.26Hz'],
    'Normal': normal_magnitude['Freq_157.26Hz']
}

# 각 데이터셋에 대해 정규성 검정 수행
for name, data in datasets.items():
    w_stat, p_value = shapiro(data)
    print(f"{name} - W-statistic: {w_stat}, p-value: {p_value}")

#outer만 정규성 X
# Out:
# Inner - W-statistic: 0.9972317581586133, p-value: 0.8809184545672075
# Outer - W-statistic: 0.9270966883249306, p-value: 3.7753414135755814e-11
# Roller - W-statistic: 0.9954176881299054, p-value: 0.49795340330245996
# Normal - W-statistic: 0.9915864794943692, p-value: 0.07686148035610586

# %%
inner_157 = inner_magnitude['Freq_157.26Hz']
outer_157 = outer_magnitude['Freq_157.26Hz']
roller_157 = roller_magnitude['Freq_157.26Hz']
normal_157 =  normal_magnitude['Freq_157.26Hz']

# %%
# Mann-Whitney U 검정
u_outer, p_outer = mannwhitneyu(inner_157, roller_157)
u_roller, p_roller = mannwhitneyu(outer_157, roller_157)
u_normal, p_normal = mannwhitneyu(normal_157, roller_157)

print("Inner vs Outer - U-statistic:", u_outer, ", p-value:", p_outer)
print("Inner vs Roller - U-statistic:", u_roller, ", p-value:", p_roller)
print("Inner vs Normal - U-statistic:", u_normal, ", p-value:", p_normal)
# Out:
# Inner vs Outer - U-statistic: 94463.0 , p-value: 2.1591922844737502e-98
# Inner vs Roller - U-statistic: 203.0 , p-value: 8.706969055226091e-102
# Inner vs Normal - U-statistic: 0.0 , p-value: 1.7732563113966688e-102

# %%
# Kruskal-Wallis 검정 수행
kruskal_stat, kruskal_p_value = kruskal(inner_157, outer_157, roller_157, normal_157)

print("Kruskal-Wallis H-statistic:", kruskal_stat)
print("p-value:", kruskal_p_value)
# Out:
# Kruskal-Wallis H-statistic: 1150.9876322257887
# p-value: 3.1554660762668e-249

# %%
plt.figure(figsize=(10, 6))
plt.boxplot([inner_157, outer_157, roller_157, normal_157], tick_labels=['Inner', 'Outer', 'Roller', 'Normal'])
plt.title('Distribution of Freq_157.26Hz for Different Datasets')
plt.ylabel('Magnitude')
plt.grid(True)
plt.show()

# %% [markdown]
# ### csv 저장

# %%
inner_magnitude
# Out:
#      Freq_12.1Hz  Freq_157.26Hz  Freq_232.74Hz  Freq_76.03Hz
# 0     616.268988    2787.739273    1174.187236   1458.438191
# 1     207.098009    2873.517758     882.749784   1154.281556
# 2     422.675645    2637.080419    1128.925582   1355.434796
# 3     182.750802    2728.718174    1112.879855   1060.009080
# 4     396.167207    2770.208135     928.985337   1157.996111
# ..           ...            ...            ...           ...
# 305   176.919455    2965.480582    1035.275398   1071.766880
# 306   262.292223    2703.398558    1054.284086   1301.076994
# 307   168.861997    3118.370836    1084.402142   1137.655172
# 308   251.408543    2696.604876     956.133498   1189.925834
# 309   440.184504    2952.613264    1289.727833   1093.423923
#
# [310 rows x 4 columns]

# %%
inner_magnitude['fault_type'] = 1
roller_magnitude['fault_type'] = 2
outer_magnitude['fault_type'] = 3
normal_magnitude['fault_type'] = 0

# %%
learning2 = pd.concat([inner_magnitude, roller_magnitude, outer_magnitude, normal_magnitude], ignore_index=True)

# %%
learning2
# Out:
#       Freq_12.1Hz  Freq_157.26Hz  Freq_232.74Hz  Freq_76.03Hz  fault_type
# 0      616.268988    2787.739273    1174.187236   1458.438191           1
# 1      207.098009    2873.517758     882.749784   1154.281556           1
# 2      422.675645    2637.080419    1128.925582   1355.434796           1
# 3      182.750802    2728.718174    1112.879855   1060.009080           1
# 4      396.167207    2770.208135     928.985337   1157.996111           1
# ...           ...            ...            ...           ...         ...
# 1234   109.460797     396.155495     315.042338    360.887477           0
# 1235   106.936037     387.238379     293.976590    379.633629           0
# 1236   113.210066     408.432219     371.249572    384.355320           0
# 1237   111.799995     387.396616     295.473329    354.604154           0
# 1238   109.454190     382.490041     317.208386    333.088199           0
#
# [1239 rows x 5 columns]

# %%
learning2 = learning2.rename(columns={
    'Freq_12.1Hz': 'FTF_data',
    'Freq_157.26Hz': 'BPFO_data',
    'Freq_232.74Hz': 'BPFI_data',
    'Freq_76.03Hz': 'BSF_data'
})

# 변경된 결과 확인
print(learning2.head())
# Out:
#      FTF_data    BPFO_data    BPFI_data     BSF_data  fault_type
# 0  616.268988  2787.739273  1174.187236  1458.438191           1
# 1  207.098009  2873.517758   882.749784  1154.281556           1
# 2  422.675645  2637.080419  1128.925582  1355.434796           1
# 3  182.750802  2728.718174  1112.879855  1060.009080           1
# 4  396.167207  2770.208135   928.985337  1157.996111           1

# %%
import os
folder_path = r"C:\Users\medici\901"
file_name = "inner_magnitude.csv"
file_path = os.path.join(folder_path, file_name)

inner1 = pd.read_csv(file_path)

print(inner1.head())
# Out:
#       Freq_11Hz    Freq_140Hz  Freq_219.7Hz  Freq_64.69Hz
# 0   2200.769903   4327.878763   8389.776793   2581.446329
# 1  11539.629574  17578.102331  19151.411555  17345.107060
# 2  10422.500951  17890.496095  18704.516368  14969.934173
# 3   5505.022431   8882.389391  13984.089825   8147.900948
# 4   2520.057595   4167.467604   9068.812238   2888.956012

# %%
file_name = "roller_magnitude.csv"
file_path = os.path.join(folder_path, file_name)
roller1 = pd.read_csv(file_path)

# %%
file_name = "outer_magnitude.csv"
file_path = os.path.join(folder_path, file_name)
outer1 = pd.read_csv(file_path)

# %%
file_name = "normal_magnitude.csv"
file_path = os.path.join(folder_path, file_name)
normal1 = pd.read_csv(file_path)

# %%
inner1['fault_type'] = 1
roller1['fault_type'] = 2
outer1['fault_type'] = 3
normal1['fault_type'] = 0

# %%
inner1
# Out:
#         Freq_11Hz    Freq_140Hz  Freq_219.7Hz  Freq_64.69Hz  fault_type
# 0     2200.769903   4327.878763   8389.776793   2581.446329           1
# 1    11539.629574  17578.102331  19151.411555  17345.107060           1
# 2    10422.500951  17890.496095  18704.516368  14969.934173           1
# 3     5505.022431   8882.389391  13984.089825   8147.900948           1
# 4     2520.057595   4167.467604   9068.812238   2888.956012           1
# ..            ...           ...           ...           ...         ...
# 115   2614.578647   5743.797266   8247.195746   3032.218473           1
# 116   1443.108037   4304.606114   7854.350236   2161.946396           1
# 117   2719.578667   5140.552722   7545.163795   3738.397977           1
# 118   5967.247811   8933.502605   9378.328569   8278.303847           1
# 119   6809.769920  11730.247106  13076.552604   9936.665588           1
#
# [120 rows x 5 columns]

# %%
learning1 = pd.concat([inner1, roller1, outer1, normal1], ignore_index=True)

# %%
learning1
# Out:
#         Freq_11Hz    Freq_140Hz  Freq_219.7Hz  Freq_64.69Hz  fault_type
# 0     2200.769903   4327.878763   8389.776793   2581.446329           1
# 1    11539.629574  17578.102331  19151.411555  17345.107060           1
# 2    10422.500951  17890.496095  18704.516368  14969.934173           1
# 3     5505.022431   8882.389391  13984.089825   8147.900948           1
# 4     2520.057595   4167.467604   9068.812238   2888.956012           1
# ..            ...           ...           ...           ...         ...
# 475   1304.965452   3747.028102   8371.771273   1824.342832           0
# 476   1425.227501   3692.247035   6129.134755   1812.329751           0
# 477   1448.812269   4500.901762   7832.791175   2028.969519           0
# 478   1258.621499   3827.615339   7965.149458   1868.468276           0
# 479   1353.960985   5025.643632   6846.523255   1942.250202           0
#
# [480 rows x 5 columns]

# %%
learning1 = learning1.rename(columns={
    'Freq_11Hz': 'FTF_data',
    'Freq_140Hz': 'BPFO_data',
    'Freq_219.7Hz': 'BPFI_data',
    'Freq_64.69Hz': 'BSF_data'
})

# 변경된 결과 확인
print(learning1.head())
# Out:
#        FTF_data     BPFO_data     BPFI_data      BSF_data  fault_type
# 0   2200.769903   4327.878763   8389.776793   2581.446329           1
# 1  11539.629574  17578.102331  19151.411555  17345.107060           1
# 2  10422.500951  17890.496095  18704.516368  14969.934173           1
# 3   5505.022431   8882.389391  13984.089825   8147.900948           1
# 4   2520.057595   4167.467604   9068.812238   2888.956012           1

# %%
data = pd.concat([learning1, learning2], ignore_index=True)

# %%
data
# Out:
#           FTF_data     BPFO_data     BPFI_data      BSF_data  fault_type
# 0      2200.769903   4327.878763   8389.776793   2581.446329           1
# 1     11539.629574  17578.102331  19151.411555  17345.107060           1
# 2     10422.500951  17890.496095  18704.516368  14969.934173           1
# 3      5505.022431   8882.389391  13984.089825   8147.900948           1
# 4      2520.057595   4167.467604   9068.812238   2888.956012           1
# ...            ...           ...           ...           ...         ...
# 1714    109.460797    396.155495    315.042338    360.887477           0
# 1715    106.936037    387.238379    293.976590    379.633629           0
# 1716    113.210066    408.432219    371.249572    384.355320           0
# 1717    111.799995    387.396616    295.473329    354.604154           0
# 1718    109.454190    382.490041    317.208386    333.088199           0
#
# [1719 rows x 5 columns]

# %%
data.to_csv('fault frequency.csv', index = False)
